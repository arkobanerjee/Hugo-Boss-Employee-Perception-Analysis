# %% [markdown]
# # Gathering Kununu Data using API
# -------------------
#
# > <i>Description: We Gather Kununu data using their API and save them in a csv file.</i>
#
# Output:
# 1) Kununu_reviews_gathered.csv

# %%
import requests
import json
import pandas as pd
import time

# %%
# getting all the reviews

rows = []

# Loop through all pages (from 1 to 61)
for page in range(1, 62):  
    # The URL with the page number parameter
    url = f'https://www.kununu.com/middlewares/profiles/de/hugo-boss8/e7bab9db-ca2f-46c7-869a-1cdc1bea972c/reviews?fetchFactorScores=0&reviewType=employees&urlParams=&page={page}'
    
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        print('request successfull for page: ', page)
        
        if 'reviews' in data:
            for r in data['reviews']:
                # saving them in a row
                new_row = {
                    'uuid': r['uuid'],
                    'type': r['type'],
                    'title': r['title'],
                    'score': r['score'],
                    'createdAt': r['createdAt'],
                    'ratings': str(r['ratings']),  
                    'responses': str(r['responses']),
                    'texts': str(r['texts']), 
                    'position': r.get('position', 'N/A'),  
                    'company': r.get('company', 'N/A'),
                    'department': r.get('department', 'N/A'),
                    'reactions': str(r['reactions']),  
                    'recommended': r.get('recommended', 'N/A'),
                    'trainee': r.get('trainee', 'N/A'),
                    'helpful': r.get('helpful', 'N/A')
                }

                rows.append(new_row)

    else:
        print(f"Failed to retrieve data from page {page}. Status code: {response.status_code}")
    
    # Wait for 3 seconds
    time.sleep(3)

df = pd.DataFrame(rows)

df.head(5)
# Out:
# request successfull for page:  1
# request successfull for page:  2
# request successfull for page:  3
# request successfull for page:  4
# request successfull for page:  5
# request successfull for page:  6
# request successfull for page:  7
# request successfull for page:  8
# request successfull for page:  9
# request successfull for page:  10
# request successfull for page:  11
# request successfull for page:  12
# request successfull for page:  13
# request successfull for page:  14
# request successfull for page:  15
# request successfull for page:  16
# request successfull for page:  17
# request successfull for page:  18
# request successfull for page:  19
# request successfull for page:  20
# request successfull for page:  21
# request successfull for page:  22
# request successfull for page:  23
# request successfull for page:  24
# request successfull for page:  25
# request successfull for page:  26
# request successfull for page:  27
# request successfull for page:  28
# request successfull for page:  29
# request successfull for page:  30
# request successfull for page:  31
# request successfull for page:  32
# request successfull for page:  33
# request successfull for page:  34
# request successfull for page:  35
# request successfull for page:  36
# request successfull for page:  37
# request successfull for page:  38
# request successfull for page:  39
# request successfull for page:  40
# request successfull for page:  41
# request successfull for page:  42
# request successfull for page:  43
# request successfull for page:  44
# request successfull for page:  45
# request successfull for page:  46
# request successfull for page:  47
# request successfull for page:  48
# request successfull for page:  49
# request successfull for page:  50
# request successfull for page:  51
# request successfull for page:  52
# request successfull for page:  53
# request successfull for page:  54
# request successfull for page:  55
# request successfull for page:  56
# request successfull for page:  57
# request successfull for page:  58
# request successfull for page:  59
# request successfull for page:  60
# request successfull for page:  61
#                                    uuid            type  \
# 0  ca6e64a6-c45e-4b04-9d85-8ff633cbe289        employer
# 1  b11b7978-d151-4249-a747-3ba7501e1bad        employer
# 2  fe76c408-b3a7-4e8d-be08-4bb67d0868da  apprenticeship
# 3  fdd82a74-7524-4567-9844-1e3eed861f8c        employer
# 4  977c452c-f91c-4f2f-ae7d-b26e045eaddb        employer
#
#                                                title  score  \
# 0                            Außen hui, innen "pfui"    3.7
# 1  Top Arbeitgeber / Logistik sehr eingefahrenes ...    3.3
# 2     Vielseitige und tolle Ausbildung bei Hugo Boss    4.8
# 3                                Fairer Arbeitsgeber    3.8
# 4                                 Guter Arbeitgeber!    4.5
#
#                    createdAt  \
# 0  2024-09-21T00:00:00+00:00
# 1  2024-09-05T00:00:00+00:00
# 2  2024-08-30T00:00:00+00:00
# 3  2024-08-17T00:00:00+00:00
# 4  2024-08-01T00:00:00+00:00
#
#                                              ratings responses  \
# 0  [{'id': 'salary', 'score': 2, 'roundedScore': ...        []
# 1  [{'id': 'atmosphere', 'score': 4, 'roundedScor...        []
# 2  [{'id': 'apprenticeshiptasks', 'score': 4, 'ro...        []
# 3  [{'id': 'atmosphere', 'score': 5, 'roundedScor...        []
# 4  [{'id': 'atmosphere', 'score': 5, 'roundedScor...        []
#
#                                                texts    position  \
# 0  [{'id': 'negative', 'text': 'Es wird viel zu v...    employee
# 1  [{'id': 'positive', 'text': 'Ein super Arbeitg...    employee
# 2  [{'id': 'positive', 'text': 'Die vielen Mitarb...  apprentice
# 3  [{'id': 'positive', 'text': 'Die Bezahlung ist...  contractor
# 4  [{'id': 'positive', 'text': 'Gutes Image, toll...    employee
#
#                                              company   department  \
# 0  {'uuid': '6fe20a30-2765-4b36-81e0-b402bc8d08ee...  procurement
# 1  {'uuid': '6fe20a30-2765-4b36-81e0-b402bc8d08ee...     logistic
# 2  {'uuid': '6fe20a30-2765-4b36-81e0-b402bc8d08ee...   operations
# 3  {'uuid': '6fe20a30-2765-4b36-81e0-b402bc8d08ee...        sales
# 4  {'uuid': '6fe20a30-2765-4b36-81e0-b402bc8d08ee...  controlling
#
#                                            reactions recommended  \
# 0  {'agree': {'total': 0, 'userReaction': None}, ...       False
# 1  {'agree': {'total': 0, 'userReaction': None}, ...        True
# 2  {'agree': {'total': 0, 'userReaction': None}, ...        True
# 3  {'agree': {'total': 0, 'userReaction': None}, ...        True
# 4  {'agree': {'total': 0, 'userReaction': None}, ...        True
#
#                                 trainee helpful
# 0                                  None     N/A
# 1                                  None     N/A
# 2  {'status': 'current', 'since': None}     N/A
# 3                                  None     N/A
# 4                                  None     N/A

# %%
print('total reviews count: ', len(df))

duplicate_uuids = df[df.duplicated(subset='uuid', keep=False)]
duplicate_uuid_counts = duplicate_uuids['uuid'].value_counts()

# Display the duplicates
print('number of duplicates: ',len(duplicate_uuid_counts))
# Out:
# total reviews count:  607
# number of duplicates:  0

# %%
# locations of Hugo Boss
df['company'].value_counts()
# Out:
# {'uuid': '6fe20a30-2765-4b36-81e0-b402bc8d08ee', 'name': 'HUGO BOSS AG', 'location': {'countryCode': 'de', 'state': 'Baden-Württemberg', 'city': 'Metzingen'}}               491
# {'uuid': 'd6b633c3-1bae-4347-8a9b-b4f31342fad1', 'name': 'Hugo Boss AG, Metzingen', 'location': {'countryCode': 'de', 'state': 'Baden-Württemberg', 'city': 'Stuttgart'}}     35
# {'uuid': '1de3f38b-4998-4db2-b9fd-db8d91cbac2f', 'name': 'Hugo Boss', 'location': {'countryCode': 'de', 'state': 'Berlin', 'city': 'Berlin'}}                                 17
# {'uuid': 'ae535fd9-4c34-4d68-ad2a-b4908924393c', 'name': 'HUGO BOSS', 'location': {'countryCode': 'de', 'state': 'Baden-Württemberg', 'city': 'Stuttgart'}}                   16
# {'uuid': 'dd8ebe1e-92b6-4455-b69c-b283335419f1', 'name': 'HUGO BOSS AG', 'location': {'countryCode': 'de', 'state': 'Hessen', 'city': 'Frankfurt am Main'}}                   11
# {'uuid': '072ba005-ca7a-4edd-849a-5ce3c158783d', 'name': 'HUGO BOSS AG', 'location': {'countryCode': 'de', 'state': 'Berlin', 'city': 'Berlin'}}                               8
# {'uuid': 'd0bcf47a-6333-47dd-aab5-4992754343e0', 'name': 'Hugo Boss AG', 'location': {'countryCode': 'de', 'state': 'Nordrhein-Westfalen', 'city': 'Düsseldorf'}}              6
# {'uuid': '454f39c0-475a-47e7-8a2f-d31e3d0e3b12', 'name': 'Hugo Boss', 'location': {'countryCode': 'de', 'state': 'Bayern', 'city': 'München'}}                                 5
# {'uuid': '86ffbf81-726c-458a-ac05-ecdbed73085d', 'name': 'HUGO BOSS AG', 'location': {'countryCode': 'de', 'state': 'Baden-Württemberg', 'city': 'Balingen'}}                  4
# {'uuid': '446e6ee2-7f71-4118-a4d9-1232f99d5931', 'name': 'HUGO BOSS AG', 'location': {'countryCode': 'de', 'state': 'Hamburg', 'city': 'Hamburg'}}                             4
# {'uuid': '70d088df-7bc9-4f9d-9bd6-ded0643c4c1f', 'name': 'HUGO BOSS AG', 'location': {'countryCode': None, 'state': None, 'city': None}}                                       2
# {'uuid': 'f44fe8f3-fc14-4f2e-99ff-e35a8bc0fe3b', 'name': 'HUGO BOSS AG', 'location': {'countryCode': 'de', 'state': 'Baden-Württemberg', 'city': 'Wendlingen am Neckar'}}      2
# {'uuid': '471c7076-0785-4061-8aba-47854e1146d2', 'name': 'HUGO BOSS AG', 'location': {'countryCode': 'de', 'state': 'Baden-Württemberg', 'city': 'Filderstadt'}}               2
# {'uuid': '8483c73f-f063-42a3-8252-10e5eab06808', 'name': 'Hugo Boss AG', 'location': {'countryCode': None, 'state': None, 'city': None}}                                       1
# {'uuid': '28374fca-a12d-428e-963f-1f6796694a5f', 'name': 'HUGO BOSS AG', 'location': {'countryCode': 'de', 'state': 'Brandenburg', 'city': 'Wustermark'}}                      1
# {'uuid': 'e86b8aba-8d43-4cc9-a3cd-48ac4d4e1d9b', 'name': 'Hugo Boss', 'location': {'countryCode': 'de', 'state': 'Schleswig-Holstein', 'city': 'Neumünster'}}                  1
# {'uuid': 'a719935e-e44a-4b65-ae96-cfb45cf4a957', 'name': 'Hugo Boss AG', 'location': {'countryCode': 'de', 'state': 'Nordrhein-Westfalen', 'city': 'Köln'}}                    1
# Name: company, dtype: int64

# %% [markdown]
# ## based on Kununu Frontend:
# ### 608 reviews from employees
# ### kununu Score : 3.8
# ### Recommendation : 76%

# %%
df.to_csv('Kununu_reviews_gathered.csv')

# %% [markdown]
# ## End of Notebook
